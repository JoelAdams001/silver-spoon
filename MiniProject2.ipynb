# %%
# Mini Project 2: Madlib Generator!!
from random import randint
x = randint(1,10)
print("The madlib randomizer has chosen story number %s!!" % x)

if x == 1:  
    #Number 1: Runaway Bride Proposal
    #Source: www.madtakes.com/libs/180.html
    x1 = input("Enter an adjective: ")
    x2 = input("Now enter a noun: ")
    x3 = input("Please enter a number: ")
    x4 = input("Okay, now another noun: ")
    x5 = input("Now time for another ajective: ")
    x6 = input("Please enter a verb: ")
    x7 = input("Enter a noun please: ")
    x8 = input("A lil different question here. Enter a body part: ")
    x9 = input("Finally, enter an adjective: ")

    print('''
        Look, I guarantee there`ll be %s times. I guarantee that at some %s,
        # %s or both of us is gonna want to get out of this %s. But I also guarantee that
        if I don`t ask you to be %s, I`ll %s it for the rest of my %s,
        because I know, in my %s, you`re the %s one for me.
        ''' % (x1,x2,x3,x4,x5,x6,x7,x8,x9))	

if x == 2:
    #Number 2: Be Kind
    #Source: www.madtakes.com/libs/188.html
    x1 = input("Enter a noun: ")
    x2 = input("Again, a noun but plural: ")
    x3 = input("A noun once again: ")
    x4 = input("Let's switch it up now. Enter a place: ")
    x5 = input("Now time for an ajective: ")
    x6 = input("Finally, a noun again: ")
    
    print('''
        Be kind to your %s-footed %s
        For a duck may be somebody`s %s,
        Be kind to your %s in %s
        Where the weather is always %s.
        
        You may think that this is the %s,
        Well it is.	
        ''' % (x1,x2,x3,x2,x4,x5,x6))	
    
if x == 3:
    #Number 3: 
    #Source: Original by me
    x1 = input("Enter a noun: ")
    x2 = input("Now enter a verb: ")
    x3 = input("Enter a different verb: ")
    x4 = input("Enter the name of a good friend you know: ")
    x5 = input("Enter a number: ")
    
    print('''
        One of the most precious valuables in your life is your %s.
        Sure, it might %s sometimes, but hey, it be like that sometimes.
        The darn thing did once %s with %s. Well... actually, it did %s times...
        Still, you love your %s.
        ''' % (x1,x2,x3,x4,x5,x1))

if x == 4:
    #Number 4: Romantic Poetry
    #Source: www.madtakes.com/libs/013.html
    x1 = input("Enter a color: ")
    x2 = input("Enter a plural noun: ")
    x3 = input("Awesome, just a regular noun now: ")
    x4 = input("Lastly, enter an adjective: ")

    print('''
        Roses are %s, 
        # %s are blue, 
        # %s is %s, 
        and so are you. 
        ''' % (x1,x2,x3,x4))
    
if x == 5:
    #Number 5: There Was an Old Woman
    #Source: www.madtakes.com/libs/019.html
    x1 = input("Give me an adjective: ")
    x2 = input("Gimme a noun now: ")
    x3 = input("A plural noun: ")
    x4 = input("A noun noun: ")
    x5 = input("A verb ending in \"ed\": ")

    print('''
        There was an %s woman who lived in a %s. 
        She had so many %s she didn`t know what to do. 
        She gave them some broth without any %s. 
        She %s them all soundly and put them to bed. 
        ''' % (x1,x2,x3,x4,x5))

if x == 6:
    #Number 6: Katie's Kapers
    #Source: www.madtakes.com/libs/023.html
    x1 = input("Verb ending in \"ing\": ")
    x2 = input("Gimme a noun now: ")
    x3 = input("Enter a part of the body: ")
    x4 = input("Enter a verb: ")
    x5 = input("Now an animal: ")
    x6 = input("Finally, a verb ending in \"ed\": ")

    print('''
       I was %s down the hallway and some %s
       grabbed my %s, and I turned to him and said "so help me,
       if you %s me again you will go the way of the %s."
       And then he %s away. 
        ''' % (x1,x2,x3,x4,x5,x6))
    
if x == 7:
    #Number 7: The New Day
    #Source: www.madtakes.com/libs/086.html
    x1 = input("Verb ending in \"ing\": ")
    x2 = input("Yet another verb ending in \"ing\": ")
    x3 = input("Finally, a verb ending in \"ed\": ")
    x4 = input("Enter a place: ")
    x5 = input("Alrighty, now a verb: ")
    x6 = input("Let's wrap it up with another verb: ")

    print('''
        Tommorrow is a new day full of new suprises and new adventures.
        Such as %s and %s. Tommorrow leads you to the life you haven`t
        # %s yet. So why not plan to live today with the most adventurious
        and positive outlook. Because today is yesterday`s tommorrow and
        we all know that it`s good to do things differently. So let`s go to %s
        and %s with someone cool. Or you could just let it %s right by.	
        ''' % (x1,x2,x3,x4,x5,x6))
    
if x == 8:
    #Number 8: Greatings, Earthlings!
    #Source: www.madtakes.com/libs/001.html
    x1 = input("Enter a plural noun: ")
    x2 = input("Enter an occupation: ")
    x3 = input("A plural animal: ")
    x4 = input("Enter a place: ")
    x5 = input("Alrighty, now a verb: ")
    x6 = input("Let's wrap it up with another noun: ")

    print('''
        In the book War of the %s, the main character is an anonymous %s
        who records the arrival of %s in %s. Needless to say, havoc reigns
        as the %scontinue to %s everything in sight, until they are killed
        by the common %s.
        ''' % (x1,x2,x3,x4,x5,x6))
    
if x == 9:
    #Number 9: The Industry's Most Highly Awarded...
    #Source: www.madtakes.com/libs/007.html
    x1 = input("Let's get started... Enter a company: ")
    x2 = input("Enter a noun: ")
    x3 = input("Please give me an adjective: ")
    x4 = input("Now for a plural noun: ")
    x5 = input("A regular noun: ")
    x6 = input("Type out an adjective: ")
    x7 = input("Now a noun ending in \"ers\": ")
    x8 = input("Lastly, a plural noun: ")

    print('''
        "Without doubt %s has left its %s
        with us as some of the most %s %s
        on the %s... This %s that we highly recommend
        for %s %s and high-end %s." 
        ''' % (x1,x2,x3,x4,x5,x6,x7,x8))
    
if x == 10:
    #Number 10: Old Macdonald
    #Source: www.madtakes.com/libs/185.html
    x1 = input("Please gimme an adjective: ")
    x2 = input("Enter a noun: ")
    x3 = input("Name an animal: ")
    x4 = input("Enter a noise: ")

    print('''
        # %s Macdonald had a %s, E-I-E-I-O
        and on that %s he had an %s, E-I-E-I-O
        with a %s %s here
        and a %s %s there,
        here a %s, there a %s,
        everywhere a %s %s,
        # %s Macdonald had a %s, E-I-E-I-O.	
        ''' % (x1,x2,x2,x3,x4,x4,x4,x4,x4,x4,x4,x4,x1,x2))
# Out:
# The madlib randomizer has chosen story number 4!!
# Enter a color: blue
# Enter a plural noun: ducks
# Awesome, just a regular noun now: dog
# Lastly, enter an adjective: handsom
#
#         Roses are blue,
#         ducks are blue,
#         dog is handsom,
#         and so are you.
